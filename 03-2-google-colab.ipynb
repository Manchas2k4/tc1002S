# %% [markdown]
# # Introducción a Google Colab

# %% [markdown]
# * **Google Colab** es un entorno de máquinas virtuales basado en *Jupyter Notebooks*.
# * Nos permite ejecutar programas en la nube. Solo es necesario tener un navegador Web.
# * Es posible elegir si el entorno se ejecuta en CPU, GPU o TPU (Tensor Processing Unit) de forma gratuita.
# * El entorno ya viene con muchas librerías instalas que podemos utilizar. Y, además, podemos instalar más librerías, en caso de ser necesario.
# * Sin embargo, existen algunas restricciones que tenemos que considerar.
#   * La sesión dura 12 horas. Pasado este tiempo, se limpia nuestro entorno y tendremos que ejecutar todo nuevamente.
#   * Los recursos que utilizamos (CPU, RAM) son compartidos, así que estamos sujetos a disponibilidad.

# %% [markdown]
# # Tipos de celda

# %% [markdown]
# * En Google Colab disponemos de celdas de código y celdas de texto (markdown) que pueden ir intercaladas entre sí.
# * Para insertar celdas, solo colacamos el cursos en medio de dos celdas y nos aparecerá la opción de agregar una nueva celda de código o texto.

# %% [markdown]
# ##Celdas de código

# %%
# Esta una celda de código
print("¡Hola mundo")
# Out:
# ¡Hola mundo

# %% [markdown]
# ## Celdas de texto

# %% [markdown]
# La celda de texto pueden llevar:
#
# "#Título"
#
# "##Subtítulo"
#
# "###De hecho, diferentes niveles de subtítulos".
#
# También podemos colocar texto en **negritas** o en *cursiva*. Podemos insertar hipervínculos a [páginas Web](https://tec.mx/es) o [imágenes](https://www.enroll-u.com/_i/1/7/7/4ecd9be0-eec4-11e9-9992-0231b47980f0.jpeg).
#
# Además,
# * Podemos hacer listas con viñetas.
# 2. También con números.

# %% [markdown]
# #Trabajando con Google Colab

# %% [markdown]
# ## Importar datos

# %% [markdown]
# * ¿Podemos utilizar conjuntos de datos en Google Colab? De hecho, la manera más ordenada de hacerlo es importando los archivos de **Google Drive** y manejarlo como un sistemas de archivos *on premise* (o fuera de la nube).
# * En Google Colab tenemos disponibles **fragmentos de código** que nos ayudan en varias actividades. Para utilizarlos, vamos al menú *Insertar ➡ Fragmentos de código*

# %%
#Montar nuestro Google Drive en el entorno de Google Colab
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# * Al ejecutar el código anterior, nuestra cuenta de Google nos preguntará si deseamos permitir que Google Colab acceda a nuestro Google Drive.
# * Esto nos permitirá tener acceso a las carpetas y archivos que tengamos almacenads en nuestra cuenta personal de Google Drive.
# * Para crear y manejar archivos directamente desde Google Colab podemos utilizar los comandos de **UNIX** que vimos anteriormente.

# %% [markdown]
# ## Comandos básicos de UNIX en Google Colab

# %% [markdown]
# * En Googe Colab, podemos ejecutar los comandos de UNIX que vimos anteriormente con la ayuda de los operados `%` y `!`.
# * Solo podemos ejecutar 1 comando por celda.

# %% [markdown]
# ### Navegación

# %% [markdown]
# * `pwd`, nos despliega la dirección completa del directo activo de trabajo (*printing working directory*, *pwd*)

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# `ls`, enlista todos los archivos dentro del directorio activo de trabajo.

# %%
# %ls
# Out:
# sample_data/

# %% [markdown]
# `cd`, permite cambiarnos entre directorios.

# %%
# %cd /gdrive/MyDrive
# Out:
# /gdrive/MyDrive

# %% [markdown]
# * Con el comando anterior, nos pudimos mover a la carpeta **MyDrive**, que es la que vemos cuando abrimos Google Drive en el manejador.

# %%
# %ls
# Out:
# 'Certificados de Cousera'/  'Colab Notebooks'/   Profesor/

# %% [markdown]
# ###Crear y remover directorios

# %% [markdown]
# `mkdir`, crea un directorio o carpeta.

# %%
# %mkdir test

# %%
# %ls
# Out:
# 'Certificados de Cousera'/  'Colab Notebooks'/   Profesor/   test/

# %% [markdown]
# * `rmdir, nos permite eliminar una carpeta con el nombre que especifiquiemos. Es importante hacer notar que la carpeta tiene que estar vacía.
# * Si la carpeta no está vacía, podemos utilizar el comando `rm -r nombre_directorio`.

# %%
# %rmdir test

# %%
# %ls
# Out:
# 'Certificados de Cousera'/  'Colab Notebooks'/   Profesor/

# %% [markdown]
# ####Ejercicio

# %% [markdown]
# Crea una carpeta llamada **my-files** y cambia el directorio activo a esa carpeta.

# %% [markdown]
# ###Manejo de archivos

# %% [markdown]
# * `touch, crea un archivo vacío o actualiza la fecha de uno ya existente.

# %%
# !touch text_file.txt

# %%
# %ls
# Out:
# 'Certificados de Cousera'/  'Colab Notebooks'/   Profesor/   text_file.txt

# %% [markdown]
# * `echo`, sirve para desplegar una línea de texto en la consola. También la podemos usar para agregar líneas de texto a un archivo.

# %%
# !echo "Mi primera línea de texto" >> text_file.txt

# %%
# !ls
# Out:
# 'Certificados de Cousera'  'Colab Notebooks'   Profesor   text_file.txt

# %%
# !cat text_file.txt
# Out:
# Mi primera línea de texto

# %% [markdown]
# * `cp`, copia archivos o directorios

# %%
# !cp text_file.txt text_file2.txt

# %%
# %ls
# Out:
# 'Certificados de Cousera'/  'Colab Notebooks'/   Profesor/   text_file2.txt   text_file.txt

# %% [markdown]
# * `mv`, permite mover y/o renombrar archivos de texto o directorios.

# %%
# !mv text_file2.txt another_file.txt

# %%
# %ls
# Out:
#  another_file.txt  'Certificados de Cousera'/  'Colab Notebooks'/   Profesor/   text_file.txt

# %% [markdown]
# ### Carga de archivos

# %% [markdown]
# * Para cargar archivos locales, utilizaremos el siguiente código:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-47cd96e0-0355-49c0-9a16-7854cefe2ef9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47cd96e0-0355-49c0-9a16-7854cefe2ef9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# * Nos mostrará un botón para seleccionar el archivo y cargarlo. Este código, al igual que el anterior, lo podemos obtener de la sección *Fragmentos de código*.

# %%
# %ls
# Out:
#  another_file.txt           'Colab Notebooks'/   salida.txt
# 'Certificados de Cousera'/   Profesor/           text_file.txt

# %% [markdown]
# # Github

# %% [markdown]
# * [Github](https://github.com/) es una plataforma de desarrollo para alojar proyectos utilizando el sistema de control de versiones Git.
# * Como mencionamos antes, Git nos permite llevar un seguimiento de todas las versiones de archivos de un proyecto.

# %% [markdown]
# ![github.png](data:image/png;base64,...)

# %% [markdown]
# * Ahora, será necesario que crees una cuenta en Github. Te recomendamos usar el correo del Tec, ya que te dará el acceso a una cuenta Pro con muchos beneficios.

# %% [markdown]
# ## Trabajando con Github en Google Colab

# %% [markdown]
# * Github permite compartir con nuestros proyectos con otras personas y, a su vez, que ellas hagan aportaciones al proyecto.
# * Las interacciones en Git las hacemos desde nuestra computadora local (o en este caso desde Google Colab) mientras que para Github utilizamos un navegador Web.

# %% [markdown]
# ### Crear un token para acceder desde Google Colab

# %% [markdown]
# Para crear un token,
# 1. En la página principal, vamos al ícono de perfil. Seleccionamos *Configuración*.

# %% [markdown]
# ![token1.png](data:image/png;base64,...)

# %% [markdown]
# 2. Vamos al panel izquierdo y seleccionamos *Configuración de desarrolladores*

# %% [markdown]
# ![token2.png](data:image/png;base64,...)

# %% [markdown]
# 4. Seleccionamos la opción de *Tokens personales* y damos clic en *Generar Token Nuevo*.

# %% [markdown]
# ![token3.png](data:image/png;base64,...)

# %% [markdown]
# 5. Les damos un nombre adecuado al token que se va generar. Selecciona la validez del token (se recomienda de 1 a 3 meses). Por último, seleccionamos la opción de *repo* para parmitir las operaciones de `push`, `pull`, `branch`, etc.

# %% [markdown]
# ![token4.png](data:image/png;base64,...)

# %% [markdown]
# 6. Una vez generado el token, cópialo y guárdalo. Nos podrás volver a verlo. El token **es personal** y no se recomienda compartirlo con nadie.

# %% [markdown]
# ![token5.png](data:image/png;base64,...)

# %% [markdown]
# 7. Guarda tu `nombre de usuario`y el token dentro del archivo **credenciales.json** que encontrarás en el repositorio. Ambos valores los tienes que dejar entre comillas dobles.
# 8. Adicionalmente, crea un nuevo repositorio llamado **SemanaTec** y copia el nombre de ese repositorio al archivos de credenciales.
# 9. Una vez que tenga los datos correctos, súbelos a la carpeta **SemanaTec** que se encuentra en tu Google Drive. Si no está en esa carpeta, el siguiente código no se ejecutará correctamente.

# %% [markdown]
# ###Generar la URL para poder acceder a Github desde Google Colab

# %% [markdown]
# * Asegúrate de que el archivo **credenciales.json ** está compleo y se encuentre en la carpeta actual de trabajo (SemanaTec).

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /gdrive/MyDrive/SemanaTec
# Out:
# /gdrive/MyDrive/SemanaTec

# %%
# Vamos a importar el archivo y leer los contenidos.
import json

# Lectura del archivo
with open('credenciales.json', 'r') as myfile:
    data = myfile.read()

# Leer el formato del archivo
obj = json.loads(data)

# Vamos a guardar los datos en estas variables
GIT_USERNAME = obj['user']

# token
GIT_TOKEN = obj['token']

# Repo
GIT_REPO = obj['repo']

# Creamos la ruta al repositorio de nuestra cuenta
GIT_PATH = "https://" + GIT_USERNAME + ":" + GIT_TOKEN + "@github.com/" +\
            GIT_USERNAME + "/" + GIT_REPO + ".git"

# %%
# Vamos a imprimir el GIT_PATH para ver la estructura
GIT_PATH
# Out:
# 'https://Manchas2k4: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@github.com/Manchas2k4/RepositorioSemanaTec.git'

# %% [markdown]
# ###Clonar un repositorio existente

# %%
# !git clone https://github.com/Manchas2k4/RepositorioSemanaTec.git
# Out:
# Cloning into 'RepositorioSemanaTec'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# %ls
# Out:
# credenciales.json  datasets/  RepositorioSemanaTec/

# %%
# %cd RepositorioSemanaTec/
# Out:
# /gdrive/MyDrive/SemanaTec/RepositorioSemanaTec

# %%
# %ls
# Out:
# README.md

# %% [markdown]
# * Los repositorios clonados pertenecen a un *tercero*. Tenemos que cambiar el **remote** para que podamos ligar lo que tenemos en Google Drive con nuestro repositorio propio.

# %% [markdown]
# ###Agregar un **remote** nuevo a Git

# %% [markdown]
# * Primero, veamos cuál es el **remote** asociado al repositorio original que clonamos.

# %%
# !git remote -v
# Out:
# origin	https://github.com/Manchas2k4/RepositorioSemanaTec.git (fetch)
# origin	https://github.com/Manchas2k4/RepositorioSemanaTec.git (push)

# %% [markdown]
# * Ahora, actualicemos el nombre del repositorio.

# %%
# !git remote rename origin curso_fuente

# %% [markdown]
# * Agregaremos el **remote** con el set-url con la dirección de nuestro Github perrsonal.

# %%
# !git remote add origin "{GIT_PATH}"

# %% [markdown]
# * Comprobemos cuál es el nuevo remote.

# %%
# !git remote -v
# Out:
# curso_fuente	https://github.com/Manchas2k4/RepositorioSemanaTec.git (fetch)
# curso_fuente	https://github.com/Manchas2k4/RepositorioSemanaTec.git (push)
# origin	https://Manchas2k4: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@github.com/Manchas2k4/RepositorioSemanaTec.git (fetch)
# origin	https://Manchas2k4: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@github.com/Manchas2k4/RepositorioSemanaTec.git (push)

# %% [markdown]
# ###Crear un nuevo archivo y actualizar el repositorio en la nueva cuenta

# %% [markdown]
# * Para que Git nos deje hacer cambios en el repositorio en línea, debemos configurar el nombre de usuario y el correo.
# * Desgraciadamente, cómo se mencionó arriba, cuando trabajos en Google Colab, debemos hacer esta configuración cada vez que  trabajemos en una nueva sesión.
# * Primero, debemos configurar el correo.

# %%
# !git config --global user.email "pperezm@tec.mx"

# %% [markdown]
# * En seguida, configuremos el usuario.

# %%
# !git config --global user.name "Pedro Pérez"

# %% [markdown]
# * Agregamos un archivo de prueba para ver los cambios.

# %%
# !echo "Agregando una línea de texto a mi README" >> README.md

# %% [markdown]
# * Agregaremos los archivos modificados al área de prueba.

# %%
# !git add .

# %% [markdown]
# * Realizamos "commit" para hacer que los cambios sean oficiales.

# %%
# !git commit -m "Cambio de remote y nuevo README"
# Out:
# [main 414db2d] Cambio de remote y nuevo README
#  1 file changed, 1 insertion(+)

# %% [markdown]
# * Revisemos los cambios que están pendientes de realizar.

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'curso_fuente/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %% [markdown]
# * `git push <remote> <branch>`, si queremos enviar los cambios al repositorio y rama que especifiquemos.
# * `git push <remote> --force`, lo usamos cuando estamos completamente seguro que los cambios que tenemos localmente son los correctos. **Cuidado:** Si no estamos seguro, esto puede causar pérdida de archivos.

# %%
# !git push origin main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 333 bytes | 111.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/Manchas2k4/RepositorioSemanaTec.git
#    2d8a162..414db2d  main -> main
