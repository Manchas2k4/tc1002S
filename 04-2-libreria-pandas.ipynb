# %% [markdown]
# # Librería `pandas`

# %%
# !pip install numpy scipy matplotlib seaborn scikit-learn -q

# %% [markdown]
# [`pandas`](https://pandas.pydata.org/) es una librería de Python especializada en el manejo y análisis de estructuras de datos.
#
# Las principales características de esta librería son:
# * Define nuevas estructuras de datos basadas en el tipo `array`de la librería *NumPy* pero agregan algunas funcionalidades.
# * Permite leer y escribir fácilmente archivos en formato CSV, Excel y bases de datos SQL.
# * Permite acceder a los datos mediantes índices o nombres para renglones y columnas.
# * Ofrece métodos para reordenar, dividr y combinar conjuntos de datos.
# * Permite trabajar con series temporales.

# %% [markdown]
# ## Lectura de archivos CSV

# %% [markdown]
# * Primero, vamos a cargar algunos archivos que vamos a necesitar: `data_xml.xml`, `page.html`, `saleman.txt`, `times.csv`, y `tmdb_5000_movies.csv`. Estos archivos se encuentran en el repositorio de la materia.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import files
#       3 uploaded = files.upload()
#       5 for fn in uploaded.keys():
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# * Importamos la librería `pandas` para usarla a lo largo de este cuaderno de trabajo.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * A continuación, cargueremos los datos del archivo a un `DataFrame` de pandas. Un `DataFrame` es un conjunto de datos estructurado en forma de tabla donde cada renglon corresponde a un registro diferente, y las columnas son las distintas características del registro.
#
# * Un `DataFrame`contiene dos índices, uno para los renglones y otro para las columnas. Se pueden acceder mediante los índices de los renglones y los nombres (o índices) de las columnas.

# %%
df = pd.read_csv('tmdb_5000_movies.csv')
# El método `head` nos permite desplegar las primeras línea de un DataFrame.
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('tmdb_5000_movies.csv')
#       2 # El método `head` nos permite desplegar las primeras línea de un DataFrame.
#       3 df.head(2)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tmdb_5000_movies.csv'

# %%
# El método `info` nos despliega información sobre el tipo de dato de las columnas (características).
df.info()

# %%
# El método `describe` nos da información estadística básica de las calumnas.
df.describe()

# %% [markdown]
# * Usando `pandas` podemos leer cualquier archivo CSV sin importar la extensión que tenga.

# %%
df = pd.read_csv('salesman.txt')
df.head()

# %% [markdown]
# * O, incluso, si utilizan separadores diferentes a la `,`.

# %%
df = pd.read_csv('times.csv', sep=';')
df.head()

# %% [markdown]
# * También, podemos asignarles nombres a las columnas (si es que no tiene uno asignado).

# %%
df = pd.read_csv('times.csv', sep=';', names=['ID', 'TIME','SCORE','CLASS'])
df.head()

# %% [markdown]
# * Algunas veces sólo necesitaremos algunas columnas. Por ejemplo, del archivo `tmdb_5000_movies.csv` sólo necesitamos las columnas `id` (1), `original_title` (6), `popularity` (8), `vote_average` (18), `vote_count` (19).

# %%
df = pd.read_csv('tmdb_5000_movies.csv', usecols=[1, 6, 8, 18, 19])
df.head(2)

# %% [markdown]
# ## Lectura de archivos HTML

# %% [markdown]
# * Podemos usar `pandas` para leer todas las tablas contenidas en un archivo HTML.

# %%
df = pd.read_html('page.html')
print('Total tables:', len(df))
print(df[0])
print(df[1])

# %%
table1 = df[0]
table1.head()

# %% [markdown]
# * También, podemos optar sólo extraer alguna tabla en particular (que tenga alguna etiqueta determinada).

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States', match='Nominal GDP')
print('Total tables:', len(df))
df_GDP = df[0]
df_GDP.head(4)

# %% [markdown]
# ## Lectura de archivos XML
# * XML es el acrónimo de Extensible Markup Language, es decir, es un lenguaje de marcado que define un conjunto de reglas para la codificación de documentos. El lenguaje de marcado es un conjunto de códigos que se pueden aplicar en el análisis de datos o la lectura de textos creados por computadoras o personas. El lenguaje XML proporciona una plataforma para definir elementos para crear un formato y generar un lenguaje personalizado.

# %%
df = pd.read_xml('data_xml.xml')
df.head()

# %% [markdown]
# ## Crear `Series` usando una lista de valores

# %%
s = pd.Series([1, 3, 5, np.nan, 9, 11])
s

# %%
s[0]

# %% [markdown]
# ## Crear un `DataFrame`

# %% [markdown]
# * Vamos a crear un `DataFrame` que contenga números aleatorios en donde los índices sean las fechas des el primero de enero de 2020 hasta el 6 de enero de 20202. El `DataFrame` tendrá 4 columnas, llamadas `A`, `B`, `C` y `D`.

# %%
dates = pd.date_range('20200101', periods=6)
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df.head()
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492 -0.533736  1.118109
# 2020-01-02 -0.406651  1.563322  1.138195  0.356028
# 2020-01-03 -0.093066  1.016498 -0.512645  0.688105
# 2020-01-04 -0.320599  0.931979 -2.051235  0.221298
# 2020-01-05 -0.830595  0.305530 -0.601467  1.247763

# %% [markdown]
# * También, podemos crear un `DataFrame` con diferentes objetos.

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20200101'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': pd.Series(2, index=list(range(4)), dtype='float32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'})
df2
# Out:
#      A          B    C    D      E    F
# 0  1.0 2020-01-01  1.0  2.0   test  foo
# 1  1.0 2020-01-01  1.0  2.0  train  foo
# 2  1.0 2020-01-01  1.0  2.0   test  foo
# 3  1.0 2020-01-01  1.0  2.0  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D          float32
# E         category
# F           object
# dtype: object

# %% [markdown]
# ## Visualizando los primeros y últimos valores de un `DataFrame`

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492 -0.533736  1.118109
# 2020-01-02 -0.406651  1.563322  1.138195  0.356028

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2020-01-05 -0.830595  0.305530 -0.601467  1.247763
# 2020-01-06 -0.345935 -0.486864  0.305955 -0.085704

# %% [markdown]
# ## Transponer la información

# %% [markdown]
# * En otras palabras, convertir las columnas en índices y los índices en columnas.

# %%
df.T
# Out:
#    2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-06
# A    0.789088   -0.406651   -0.093066   -0.320599   -0.830595   -0.345935
# B    1.601492    1.563322    1.016498    0.931979    0.305530   -0.486864
# C   -0.533736    1.138195   -0.512645   -2.051235   -0.601467    0.305955
# D    1.118109    0.356028    0.688105    0.221298    1.247763   -0.085704

# %% [markdown]
# ## Seleccionando columnas

# %% [markdown]
# * Para seleccionar lso valores de la columna `A`, tenemos las siguiente opciones:

# %%
df["A"]
# Out:
# 2020-01-01    0.789088
# 2020-01-02   -0.406651
# 2020-01-03   -0.093066
# 2020-01-04   -0.320599
# 2020-01-05   -0.830595
# 2020-01-06   -0.345935
# Freq: D, Name: A, dtype: float64

# %%
df['A']
# Out:
# 2020-01-01    0.789088
# 2020-01-02   -0.406651
# 2020-01-03   -0.093066
# 2020-01-04   -0.320599
# 2020-01-05   -0.830595
# 2020-01-06   -0.345935
# Freq: D, Name: A, dtype: float64

# %%
df.A
# Out:
# 2020-01-01    0.789088
# 2020-01-02   -0.406651
# 2020-01-03   -0.093066
# 2020-01-04   -0.320599
# 2020-01-05   -0.830595
# 2020-01-06   -0.345935
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# ## Seleccionando renglones

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492 -0.533736  1.118109
# 2020-01-02 -0.406651  1.563322  1.138195  0.356028
# 2020-01-03 -0.093066  1.016498 -0.512645  0.688105

# %%
df['2020-01-01':'2020-01-03']
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492 -0.533736  1.118109
# 2020-01-02 -0.406651  1.563322  1.138195  0.356028
# 2020-01-03 -0.093066  1.016498 -0.512645  0.688105

# %% [markdown]
# ## Seleccionar por posición

# %% [markdown]
# * Si queremos seleccionar los renglones con 2020-01-04 y 2020-01-05 además de las columnas `A` y `B`.

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2020-01-04 -0.320599  0.931979
# 2020-01-05 -0.830595  0.305530

# %% [markdown]
# * Y, si necesitamos seleccionar el primer valor del primer renglón.

# %%
df.iloc[0,0]
# Out:
# np.float64(0.789088098416167)

# %% [markdown]
# ## Filtrar valores

# %% [markdown]
# * Seleccionar solo aquellas columnas del `DataFrame` `df` que tenga un valor mayor a 0.

# %%
df
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492 -0.533736  1.118109
# 2020-01-02 -0.406651  1.563322  1.138195  0.356028
# 2020-01-03 -0.093066  1.016498 -0.512645  0.688105
# 2020-01-04 -0.320599  0.931979 -2.051235  0.221298
# 2020-01-05 -0.830595  0.305530 -0.601467  1.247763
# 2020-01-06 -0.345935 -0.486864  0.305955 -0.085704

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492       NaN  1.118109
# 2020-01-02       NaN  1.563322  1.138195  0.356028
# 2020-01-03       NaN  1.016498       NaN  0.688105
# 2020-01-04       NaN  0.931979       NaN  0.221298
# 2020-01-05       NaN  0.305530       NaN  1.247763
# 2020-01-06       NaN       NaN  0.305955       NaN

# %% [markdown]
# * Seleecionar los renglones del `DataFrame` `df` en los que la columna `A` sea mayor a 0.

# %%
df[df.B > 0]
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492 -0.533736  1.118109
# 2020-01-02 -0.406651  1.563322  1.138195  0.356028
# 2020-01-03 -0.093066  1.016498 -0.512645  0.688105
# 2020-01-04 -0.320599  0.931979 -2.051235  0.221298
# 2020-01-05 -0.830595  0.305530 -0.601467  1.247763

# %% [markdown]
# * Seleecionmar los renglones del `DataFrame` `df2` donde los valores de la columna `E` tienen los valores `test` u `otro`.

# %%
df2
# Out:
#      A          B    C    D      E    F
# 0  1.0 2020-01-01  1.0  2.0   test  foo
# 1  1.0 2020-01-01  1.0  2.0  train  foo
# 2  1.0 2020-01-01  1.0  2.0   test  foo
# 3  1.0 2020-01-01  1.0  2.0  train  foo

# %%
df2[df2['E'].isin(['test','otro'])]
# Out:
#      A          B    C    D     E    F
# 0  1.0 2020-01-01  1.0  2.0  test  foo
# 2  1.0 2020-01-01  1.0  2.0  test  foo

# %% [markdown]
# ## Trabajando con información faltante

# %%
df3 = df[df > 0]
df3
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492       NaN  1.118109
# 2020-01-02       NaN  1.563322  1.138195  0.356028
# 2020-01-03       NaN  1.016498       NaN  0.688105
# 2020-01-04       NaN  0.931979       NaN  0.221298
# 2020-01-05       NaN  0.305530       NaN  1.247763
# 2020-01-06       NaN       NaN  0.305955       NaN

# %% [markdown]
# * Eliminar los renglones en donde no haya información (`NaN`) en alguna columna.

# %%
df3.dropna(how='all')
# Out:
#                    A         B         C         D
# 2020-01-01  0.789088  1.601492       NaN  1.118109
# 2020-01-02       NaN  1.563322  1.138195  0.356028
# 2020-01-03       NaN  1.016498       NaN  0.688105
# 2020-01-04       NaN  0.931979       NaN  0.221298
# 2020-01-05       NaN  0.305530       NaN  1.247763
# 2020-01-06       NaN       NaN  0.305955       NaN

# %% [markdown]
# * Rellenar los valores faltantes (`NaN`) con el valor de 10.

# %%
df3.fillna(value=10)
# Out:
#                     A          B          C          D
# 2020-01-01   0.789088   1.601492  10.000000   1.118109
# 2020-01-02  10.000000   1.563322   1.138195   0.356028
# 2020-01-03  10.000000   1.016498  10.000000   0.688105
# 2020-01-04  10.000000   0.931979  10.000000   0.221298
# 2020-01-05  10.000000   0.305530  10.000000   1.247763
# 2020-01-06  10.000000  10.000000   0.305955  10.000000

# %% [markdown]
# ## Borrando un renglón

# %%
df4 = pd.DataFrame({ 'A': [1,2,3,4, 5],
                   'B': [10,20,30,40, 50],
                   'C': [20,40,60,80, 100]
                  },
                  index=['Linea 1', 'Linea 2', 'Linea 3', 'Linea 4', 'Linea 5'])
df4
# Out:
#          A   B    C
# Linea 1  1  10   20
# Linea 2  2  20   40
# Linea 3  3  30   60
# Linea 4  4  40   80
# Linea 5  5  50  100

# %%
df5 = df4.drop(df4.index[[4]] )
df5
# Out:
#          A   B   C
# Linea 1  1  10  20
# Linea 2  2  20  40
# Linea 3  3  30  60
# Linea 4  4  40  80

# %% [markdown]
# ## Agrupando valores

# %%
df6 = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar','foo', 'bar', 'foo', 'foo'],
                    'B': ['one', 'one', 'two', 'three',
                    'two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                    'D': np.random.randn(8)})
df6
# Out:
#      A      B         C         D
# 0  foo    one -1.501662  0.768396
# 1  bar    one -1.300010 -0.240571
# 2  foo    two  1.922394  1.051654
# 3  bar  three  1.418160  0.263967
# 4  foo    two -1.211805  0.565247
# 5  bar    two  0.566697  0.233338
# 6  foo    one  0.665638  1.674179
# 7  foo  three  1.603553 -0.092627

# %% [markdown]
# * Agrupar los renglones del `DataFrame` `df4` con base a la columna `A` y realizar la suma de las columnas `B` y `C`.

# %%
df6.groupby('A').sum()
# Out:
#                      B         C         D
# A
# bar        onethreetwo  0.684848  0.256734
# foo  onetwotwoonethree  1.478118  3.966848

# %%
df6.groupby('A').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'onethreetwo' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df6.groupby('A').mean()
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/internals/managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/internals/blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# * Agrupar los renglones del `DataFrame` `df4` con base a la columna `A` y `B, además realizar la suma de las columnas `C` y `D`.

# %%
df6.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.300010 -0.240571
#     three  1.418160  0.263967
#     two    0.566697  0.233338
# foo one   -0.836024  2.442574
#     three  1.603553 -0.092627
#     two    0.710589  1.616901

# %% [markdown]
# ## Ordenar

# %% [markdown]
# * Ordenar con base a un columna (variable).

# %%
sortA = df6.groupby('A').sum()
sortA = sortA.sort_values(by='A', ascending=False)
sortA
# Out:
#                      B         C         D
# A
# foo  onetwotwoonethree  1.478118  3.966848
# bar        onethreetwo  0.684848  0.256734

# %% [markdown]
# * Ordenar con base a varias columnas.

# %%
sortA = df6.groupby(['A','B']).sum()
sortA = sortA.sort_values(by=['A','B'], ascending=True)
sortA
# Out:
#                   C         D
# A   B
# bar one   -1.300010 -0.240571
#     three  1.418160  0.263967
#     two    0.566697  0.233338
# foo one   -0.836024  2.442574
#     three  1.603553 -0.092627
#     two    0.710589  1.616901

# %%
sortA = df6.groupby(['A','B']).sum()
sortA = sortA.sort_values(by=['A','B'], ascending=False)
sortA
# Out:
#                   C         D
# A   B
# foo two    0.710589  1.616901
#     three  1.603553 -0.092627
#     one   -0.836024  2.442574
# bar two    0.566697  0.233338
#     three  1.418160  0.263967
#     one   -1.300010 -0.240571

# %% [markdown]
# ## Unión

# %% [markdown]
# * `merge` es un método que nos permite unir dos `DataFrame` en uno solo. Para ello, es muy importante que ambos `DataFrame` compartar una columna determinada.

# %%
customer_product = {'Customer_id':pd.Series([1,2,3,4,5,6]),
  'Product':pd.Series(['Oven','Oven','Oven','Television','Television','Television'])}
customer_product = pd.DataFrame(customer_product)
customer_product
# Out:
#    Customer_id     Product
# 0            1        Oven
# 1            2        Oven
# 2            3        Oven
# 3            4  Television
# 4            5  Television
# 5            6  Television

# %%
customer = {'Customer_id':pd.Series([2,4,6]),
    'State':pd.Series(['California','California','Texas'])}
customer = pd.DataFrame(customer)
customer
# Out:
#    Customer_id       State
# 0            2  California
# 1            4  California
# 2            6       Texas

# %% [markdown]
# * Realizamos una unión, regresando los valores de la tabla izquierda.

# %%
pd.merge(customer, customer_product, on='Customer_id', how='left')
# Out:
#    Customer_id       State     Product
# 0            2  California        Oven
# 1            4  California  Television
# 2            6       Texas  Television

# %% [markdown]
# * Realizamos una unión, regresando los valores de la tabla derecha.

# %%
pd.merge(customer, customer_product, on='Customer_id', how='right')
# Out:
#    Customer_id       State     Product
# 0            1         NaN        Oven
# 1            2  California        Oven
# 2            3         NaN        Oven
# 3            4  California  Television
# 4            5         NaN  Television
# 5            6       Texas  Television

# %% [markdown]
# * O, podemos regresar solos los renglones en donde existen coincidencias.

# %%
pd.merge(customer, customer_product, on='Customer_id', how='inner')
# Out:
#    Customer_id       State     Product
# 0            2  California        Oven
# 1            4  California  Television
# 2            6       Texas  Television

# %% [markdown]
# ## El método `apply`

# %% [markdown]
# * Este método es utiliza para aplicar una función a lo largo de un eje de un `DataFrame` o una `Serie`.

# %%
df7 = pd.DataFrame({ 'A': [1,2,3,4],
                   'B': [10,20,30,40],
                   'C': [20,40,60,80]
                  },
                  index=['Linea 1', 'Linea 2', 'Linea 3', 'Linea 4'])
df7
# Out:
#          A   B   C
# Linea 1  1  10  20
# Linea 2  2  20  40
# Linea 3  3  30  60
# Linea 4  4  40  80

# %% [markdown]
# Es posible aplicar una función sobre un renglón o columna determinada.

# %%
# Función promedio
def custom_mean(row):
    return row.mean()

# axis = 0 - usando los valores de una columna
# axis = 1 - usando los valores de un renglón.
df7['D'] = df7.apply(custom_mean, axis=1)
df7
# Out:
#          A   B   C          D
# Linea 1  1  10  20  10.333333
# Linea 2  2  20  40  20.666667
# Linea 3  3  30  60  31.000000
# Linea 4  4  40  80  41.333333

# %%
def custom_sum(col):
    return col.sum()

df7.loc['Sum'] = df7.apply(custom_sum, axis=0)
df7
# Out:
#             A      B      C           D
# Linea 1   1.0   10.0   20.0   10.333333
# Linea 2   2.0   20.0   40.0   20.666667
# Linea 3   3.0   30.0   60.0   31.000000
# Linea 4   4.0   40.0   80.0   41.333333
# Sum      10.0  100.0  200.0  103.333333

# %% [markdown]
# ## El método `map'

# %% [markdown]
# * El método `map` realiza operaciones sobre una serie de valores (`Serie`).

# %%
s = pd.Series(['estufa','hornito','xbox','switch'])
s
# Out:
# 0     estufa
# 1    hornito
# 2       xbox
# 3     switch
# dtype: object

# %% [markdown]
# * Clasificaremos a cada elementos en electrodomético o consola.

# %%
s.map({'estufa':'electrodoméstico','hornito':'electrodoméstico','xbox':'consola','switch':'consola'})
# Out:
# 0    electrodoméstico
# 1    electrodoméstico
# 2             consola
# 3             consola
# dtype: object

# %% [markdown]
# ## El método `applymap`

# %% [markdown]
# * Es utilizado para realizar operaciones a través de todo el `DataFrame`.

# %%
df8 = pd.DataFrame({ 'A': [1,2,3,4],
                   'B': [10,20,30,40],
                   'C': [20,40,60,80]
                  },
                  index=['Linea 1', 'Linea 2', 'Linea 3', 'Linea 4'])
df8
# Out:
#          A   B   C
# Linea 1  1  10  20
# Linea 2  2  20  40
# Linea 3  3  30  60
# Linea 4  4  40  80

# %% [markdown]
# * Calcular el cuadrado de cada número del `DataFrame`.

# %%
df8.apply(np.square)
# Out:
#           A     B     C
# Linea 1   1   100   400
# Linea 2   4   400  1600
# Linea 3   9   900  3600
# Linea 4  16  1600  6400

# %%
df8
# Out:
#          A   B   C
# Linea 1  1  10  20
# Linea 2  2  20  40
# Linea 3  3  30  60
# Linea 4  4  40  80
