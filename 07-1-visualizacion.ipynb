# %% [markdown]
# # Visualuzación de datos

# %% [markdown]
# ## Librerías de visualización de datos

# %% [markdown]
# * **matplotlib** es la librería más utilizada para crear gráficos en Python.
#   * Está basada en la graficación de *Matlab*.
#   * Permite agregar elementos sobre el gráfico, modificar títulos y leyendas, cambiar colores, entre muchas otras funciones.
#   * Como desventaja, para cada detalle que queramos agregar es probable que requiramos agregar una línea de código.
#
# * **seaborn** es una librería que está basada en *matplotlib*.
#   * Tiene la ventaja de que los gráficos son más bonitos por defecto y que utiliza menos líneas de código.
#   * Como desventaja, para detalles muy específicos requiere que agreguemos código de matplotlib.
#
# * **plotly** es una librería para crear gráficos tipo dashboard.
#   * Las visualizaciones creadas con esta librería son interactivas.
#   * Como principal desventaja, el código para generar este tipo de gráficos es más complejo que los casos anteriores.

# %%
# Primero, importaremos las librerías básicas que usaremos en los siguientes
# ejemplos.
import numpy as np
import pandas as pd

# %% [markdown]
# ## Librería `matplotlib`

# %% [markdown]
# La utilizamos cuando trabajamos con datos simples. Nos sirve para configurar cada elemento del gráfico:
#   * Tamaño de la imagen.
#   * Tipo de gráfico.
#   * Colores y marcas
#   * Leyendas y nombres de los ejes.
#   * Título.
#   * Cuadrícula, ejes primarios y secundarios.
#
# Para utilizarla, necesitamos imporatarla:
# ```python
# import matplotlib.pyplot as plt
# ```
#
# Normalmente usamos el siguiente formato:
# ```python
# # Para configurar el tamaño de la imagen
# fig = plt.figure(figsize=(<width, height>))
# # Con la siguiente instruccion dibujamos un gráfico de línea
# plt.plot(<x>, <y>, color = <"color">, label = <"etiqueta">)
# # Las siguientes líneas son para agregar elementos del gráfico.
# plt.title(<"título">) # Para agregar el título
# plt.xlabel(<"título del eje x">) # Etiqueta del eje X
# plt.ylabel(<"título del eje y">) # Etiqueta del eje Y
# plt.legend(loc='best') # Para mostrar las etiquetas de datos.
# plt.grid(<Booleano>) # Para agregar cuadrícula
# ```

# %%
# Importamos la librería.
import matplotlib.pyplot as plt

# %% [markdown]
# Grafiquemos la función $y_1 = 0.5\cdot x$

# %%
x = np.linspace(0, 5, num=50)
y1 = 0.5 * x

# Configuramos el tamaño de imagen
fig = plt.figure(figsize=(6,4))

# Agregamos la gráfica
plt.plot(x, y1, color='b', label='y=0.5x')

# Agregamos títulos a los ejes y al gráfico
plt.xlabel('x')
plt.ylabel('y')
plt.title('Función y=0.5x')

# Cuando tenemos una sola línea, legend no hace mucho sentido.
plt.legend(loc='best')

# %% [markdown]
# Podemos agregar más de una función en el mismo gráfico. Por ejemplo, grefiquemos la función $y_2 = \sin(x)$ sobre el gráfico anterior.

# %%
# Hay que crear el vector de la segunda función
y2 = np.sin(x)

# Usamos el mismo código del gráfico anterior, pero agregamos un segundo plot

# Configuramos el tamaño de imagen
fig = plt.figure(figsize=(6,4))

# Colocamos la primera gráfica, y1, con un color determinado. En este caso azúl (b).
plt.plot(x, y1, color='b', label='y=0.5x')

# A continuación, agregamos la segunda gráfica, y2, de color rojo (r).
plt.plot(x, y2, color='r', label='y=sin(x)')

# Agregamos títulos a los ejes y al gráfico
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dos funciones')

# Aquí la leyenda hace mucho más sentido
plt.legend(loc='best')

# Agregamos la cuadrícula para que se vea mejor
plt.grid(True)

# %% [markdown]
# `plot` grafica *líneas continuas*. Si queremos graficar *puntos*, usamos la función `scatter`. Podemos mezclar los tipos de gráfico en una misma imagen.

# %%
# Configuramos el tamaño de imagen
fig = plt.figure(figsize=(6,4))

# En este ejemplo, agregaremos primero y2. El orden no importa.
plt.plot(x, y2, color='r', label='y=sin(x)')

# A continuación, agregamos la primera gráfica. Cambiamos a un scatter
plt.scatter(x, y1, color='b', label='y=0.5x')

# Agregamos títulos a los ejes y al gráfico
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dos funciones')

# Aquí la leyenda hace mucho más sentido
plt.legend(loc='best')

# Agregamos la cuadrícula para que se vea mejor
plt.grid(True)

# %% [markdown]
# También podemos graficar un conjunto de datos. Probemos con el conjunto de datos `credit.csv` que usamos en el tema pasado. Recuerda, este conjunto de datos se encuentra en el repositorio de la clase.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f54c1a4e-ef82-42b7-b025-1edb3bf4d54a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f54c1a4e-ef82-42b7-b025-1edb3bf4d54a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving credit.csv to credit.csv
# Saving iris.csv to iris.csv
# User uploaded file "credit.csv" with length 21967 bytes
# User uploaded file "iris.csv" with length 3716 bytes

# %%
df1 = pd.read_csv('credit.csv')
df1.head(3)
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580

# %% [markdown]
# Grafiquemos los ingresos contra el límite de crédito.

# %%
# Configuramos el tamaño de imagen
fig = plt.figure(figsize=(6,4))

# Graficamos los incresos contra el límite de crédito
plt.plot(df1['Income'], df1['Limit'], '*')

# Agregamos títulos a los ejes y al gráfico
plt.xlabel('Ingresos')
plt.ylabel('Límite de crédito')
plt.title('Gráfico de un conjunto de datos')

# Aquí la leyenda hace mucho más sentido
plt.legend(loc='best')

# Agregamos la cuadrícula para que se vea mejor
plt.grid(True)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Librería `seaborn`

# %% [markdown]
# Cuando trabajamos con datos *tabulares*, en `matplotlib` tenemos que configurar cada elemento del gráfico y puede resultar en muchas líneas de código. Por otro lado, `seaborn`, derivada de `mapplotlib`, nos ayuda mucho cuando queremos graficar `DataFrames` de manera rápida y en menos líneas de código.
#
# Para graficar con `seaborn`, la tabla debe tener **formato largo**. Cada columna debe representar una variable y cada renglón una observación.
#
# La forma general de graficar con `seaborn es:
# ```python
# # Importamos la librería
# import seaborn as sns
# # seaborn hace más bonitas las gráficas.
# # Usamos set para definir el estilo de Seaborn para todas las gráficas.
# sns.set()
#
# # La gráfica en sí:
# sns.<tipo_de_grafico>(data = <df>, x=<"columna X">,
#                     y = <"columna y"> , hue = <"columna color">,
#                     size = <"columna tamaño">, style = <'columna estilo'>,
#                     palette = <'paleta de colores'>, cmap,...)
# ```

# %% [markdown]
# Para los siguientes ejemplos, utilizaremos el conjunto de datos `iris.csv` (se encuentra en el repositorio de la clase). Carga el archivo usando el código que usamos para cargar el conjunto de datos `credit.csv`.

# %% [markdown]
# Este famoso conjunto de datos corresopnde a un análisis multivariado que el biólogo Ronald Fisher utilizó en su artículo de 1936 *The use of multiple measurements in taxonomic problems* para ejemplificar un análisis discriminante lineal. Los datos consisten en 4 mediciones para tres especies de flor Iris (Iris setosa, Iris virginica and Iris versicolor). Las 4 mediciones corresponden a la longitud y altura de los sépalos y de los pétalos de cada especimen.

# %% [markdown]
# ![descarga.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# Revisemos el contenido del archivo.

# %%
df2 = pd.read_csv('iris.csv')
df2.head(5)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df2.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Antes  de continuar, importamos seaborn
import seaborn as sns

# %% [markdown]
# ## Gŕaficos de barra

# %% [markdown]
# Esta visualización la usamos cuando queremos graficar los valores de una **variable categórica**.  Es el equivalente al *conteo* de las apariciones de cada clase de la variable categórica. En caso de usar `seaborn`, el conteo se hace automáticamente.

# %%
# Vamos a graficar el conteo de la variable categórica (Species)
# Tamaño de la imagen
fig = plt.figure(figsize=(6,4))

# Gráfico countplot para hacer barras con el número de apariciones de cada especie.
sns.countplot(data=df2, x = 'Species')

# Ejes y título. Colocamos la etiqueta correcta de acuerdo a la orientación.
plt.title('Observaciones de cada especie')
plt.xlabel('Especie')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Si no conviene, es posible invertir los ejes. Además, si hay muchasx categorías, lo mejor es tenerlar en el eje *y*.

# %%
# Vamos a graficar el conteo de la variable categórica (Species)
# Tamaño de la imagen
fig = plt.figure(figsize=(6, 4))

# Gráfico countplot para hacer barras con el número de apariciones de cada especie.
sns.countplot(data=df2, y = 'Species')

# Ejes y título. Colocamos la etiqueta correcta de acuerdo a la orientación.
plt.title('Observaciones de cada especie')
plt.xlabel('Frecuencia')
plt.ylabel('Especie')
# Out:
# Text(0, 0.5, 'Especie')

# %%
df3 = pd.DataFrame(data={"Pais":['Mexico','Argentina','Espana','Colombia'],
                        "Poblacion":[127212000, 45167000, 47099000, 48922000]})
df3
# Out:
#         Pais  Poblacion
# 0     Mexico  127212000
# 1  Argentina   45167000
# 2     Espana   47099000
# 3   Colombia   48922000

# %%
df3.set_index('Pais')['Poblacion'].plot(kind='bar')

# %%
df3['Superficie'] = [1964375, 2780400, 505944, 1142748]
df3
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000     2780400
# 2     Espana   47099000      505944
# 3   Colombia   48922000     1142748

# %%
df3.set_index('Pais')['Superficie'].plot(kind='area');

# %%
df3.set_index('Pais').plot.barh(stacked=True);

# %%
df3.set_index('Pais')['Superficie'].plot.pie();

# %% [markdown]
# ## Histogramas

# %% [markdown]
# Los histogramas nos ayudan a visualizar la distribución de **una sola variable numérica**. El eje $x$ está dividido en *secciones* o *cajas*. Este parámetro se llama *bins* en la función de `seaborn`. El eje $y$ muestra cuántos datos cayeron en cada *caja* en las que se dividió la variable que estamos graficando.`
#
# ```python
# # La gráfica en sí:
# sns.<tipo_de_grafico>(data = <df>, x=<"columna X">,
#                     hue = <"esquema de color"> ,
#                     bins = <"número de cajas">, kde=<True/False>)
# ```

# %% [markdown]
# * `data`: es la tabla que contiene los datos que vamos a graficar.
# * `x`: es la **variable (columna) numérica** a graficar.
# * `hue`: controla el color dependiendo de **una variable cualitativa**.
# * `bins`: es el número de cajas (barras) que va a tener el histograma. Por defecto son 10.
# * `kde`: es un parámetro para graficar una aproximación continua del histograma.

# %%
# Histograma simple
sns.histplot(data=df2, x='Sepal.Length')

# %%
# Cuando agregamos hue, separamos la variable en grupos dependiendo el valor 
# de la variable cualitativa. A medida que agregamos parámetros, vamos 
# controlando el gráfico.

# Definiendo qué esquema de color y cuántas cajas 
sns.histplot(data=df2, x='Sepal.Length', hue='Species' , bins=10, kde= True)

# %% [markdown]
# Por defecto, `seaborn` usa el nombre de las columnas para definir las etiquetas de los ejes. Sin embargo, podemos usar las funciones de `matplotlib` para modificar los elementos del gráfico y el tamaño.

# %%
# Tamaño de la imagen
fig = plt.figure(figsize=(9,6))

# Gráfico
sns.histplot(data=df2, x='Sepal.Length', hue='Species', bins=20, kde=True)

# Ejes y título
plt.xlabel('Longitud del sépalo')
plt.ylabel('Frecuencia')
plt.title('Comparación de la distribución del sépalo por especie')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del sépalo por especie')

# %% [markdown]
# También es posible usar `matplotlib` para crear histogramas. Sin embargo, no podemos lograr la misma "riqueza" visual con `seaborn`.

# %%
plt.figure(figsize=(9, 6))
df1['Income'].hist()

# Agregamos títulos a los ejes y al gráfico
plt.xlabel('Ingresos')
plt.ylabel('Miles de dólares')
plt.title('Gráfico de un conjunto de datos')

# Agregamos la cuadrícula para que se vea mejor
plt.grid(True)

# %% [markdown]
# # Gráficos de dispersión

# %% [markdown]
# Los usamos cuando queremos ver la relación entre **dos variables numéricas**. Podemos usar variables categóricas para modificar el estilo o el color de cada punto. Es más rápido (y vistoso) usar `seaborn` que `matplotlib`. Aún así, mostraremos ambas opciones.

# %%
# Graficaremos la relación entre el ancho y la longitud del sépalo.

# Tamaño de la imagen.
fig = plt.figure(figsize=(6, 4))

# Gráfico scatterplot.
sns.scatterplot(data=df2, x ='Sepal.Length', y='Sepal.Width', hue='Species')

# Ejes y título. Colocamos la etiqueta correcta de acuerdo a la orientación.
plt.title('Relación entre el ancho y la longitud del sépalo por especie')
plt.xlabel('Longitud del sépalo')
plt.ylabel('Ancho del sépalo')
# Out:
# Text(0, 0.5, 'Ancho del sépalo')

# %%
# Configuramos el tamaño de imagen
fig = plt.figure(figsize=(6,4))

# Graficamos los incresos contra el límite de crédito
plt.plot(df2['Sepal.Length'], df2['Sepal.Width'], '*')

# Agregamos títulos a los ejes y al gráfico
plt.title('Relación entre el ancho y la longitud del sépalo por especie')
plt.xlabel('Longitud del sépalo')
plt.ylabel('Ancho del sépalo')

# Agregamos la cuadrícula para que se vea mejor
plt.grid(True)

# %% [markdown]
# Si queremos visualizar la relación uno a uno entre todas las variables numéricas, podemos usar la función *pairplot*. La estructura es similar a la matriz de correlación.

# %%
# pairplot es una versión más compleja y grande del gráfico de dispersión.
sns.pairplot(data=df2, hue='Species')

# %% [markdown]
# ## Mapa de calor (Heatmap)

# %% [markdown]
# Esta técnica de visualización de datos nos muestra la magnitud de una variable que se distribuye en **dos dimensiones**. En esencia, es colorear una **tabla** donde la *intensidad* del color corresponde al *valor* de cada celda. Es muy útil cuando tenemos tablas en formato ancho, donde tenemos valores de variables en las columnas y en las filas. Normalmente, lo utilizamos para visualizar una **matriz de correlación**.

# %%
# Vamos a graficar la matriz de correlación del dataset Iris
iris_corr = df2.corr()

# Para graficar el mapa de calor usamos heatmap. No necesitamos especificar x ni y
sns.heatmap(data=iris_corr)

# %% [markdown]
# La barra lateral es el **mapa de color**, que nos muestra la correspondencia del valor de la tabla a un color en específico. Existen diferentes mapas de colores que podemos utilizar, la lista está en la siguiente liga:
#
#   * [Mapas de Color. Matplotlib](https://matplotlib.org/stable/tutorials/colors/colormaps.html)
#
# Debemos escoger el mapa de color y la escala correcta dependiendo de los datos. Sabemos que la correlación va de -1 a 1.
#
# Si nos interesa saber si la correlación es positiva o negativa, nos conviene un mapa **divergente**.

# %%
# Gráfico heatmap. Seleccionamos los valores extremos con vmin y vmax.
# El mapa de color que usaremos es de un extremo azul y del otro rojo.
# Con annot podemos desplegar el valor de cada celda
# Con square hacemos que el gráfico sea simétrico en tamaño de ejes
sns.heatmap(data=iris_corr, vmin=-1, vmax=1, cmap = 'RdBu', annot=True, square = True)

# %% [markdown]
# ## Gráficos de caja (Boxplot)

# %% [markdown]
# Un diagrama de caja (y bigotes) es un método estandarizado para representar gráficamente una serie de datos numéricos a través de sus cuartiles. Este gráfico es muy útil porque nos permite visualizar de manera rápida estos estadísticos:
#   * Primer cuartil
#   * Tercer cuartil
#   * Mediana
#   * Máximo y mínimo
#   * Valores atípicos.

# %% [markdown]
# ![descarga.png](data:image/png;base64,...)

# %% [markdown]
# Cuando graficamos **una sola variable numérica**, el boxplot es parecido a un histograma. Ayuda a ver la distribución de la variable (medida central y de dispersión).

# %%
# Tamaño de la imagen
fig = plt.figure(figsize=(9, 6))

# Gráfico boxplot
sns.boxplot(data=df2, x='Sepal.Width')

# Ejes y título
plt.title('Histograma del ancho de sépalo por especie')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho de sépalo por especie')

# %% [markdown]
# Los puntos en el histograma representan **datos atípicos** (outliers). Estos datos presentan valores extremos, es decir, que están muy por encima comparados con el resto de las observaciones.
#
# El boxplot puede graficar **una variable numérica** separada por **una variable cualitativa**. A diferencia del histograma, no se empalman la gráficas.
#
# Ahora, veamos cómo se distribuye el ancho de sépalo por especie. Esta separación la hacemos usando la variable *Species* en el eje *y*.

# %%
# Tamaño de la imagen
fig = plt.figure(figsize=(7,5))

# Gráfico boxplot
sns.boxplot(data=df2, x='Sepal.Width', y = 'Species')

# Ejes y título
plt.title('Histograma del ancho de sépalo por especie')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho de sépalo por especie')

# %% [markdown]
# La ventaja de los diagramas de caja es que podemos invertir los ejes dependiendo de cómo se presenten mejor los datos. Si la variable categorica que usamos para separar los datos **tiene muchos niveles**, lo recomendable es usarla en el eje *y*.

# %%
# Tamaño de la imagen
fig = plt.figure(figsize=(8,5))

# Gráfico boxplot. Invertimos los ejes.
sns.boxplot(data=df2, y='Sepal.Width', x='Species')

# Ejes y título. Colocamos la etiqueta correcta de acuerdo a la orientación.
plt.title('Histograma del ancho de sépalo por especie')
plt.xlabel('Especie')
plt.ylabel('Ancho del sépalo')
# Out:
# Text(0, 0.5, 'Ancho del sépalo')
